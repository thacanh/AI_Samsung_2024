# %%
#1. Hien thi danh sach
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/DataAISamsung2024/P4AI_BT1.csv')
pd.set_option('display.max_rows', None)
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 0             5.1          3.5           1.4          0.2      Setosa
# 1             4.9          3.0           NaN          0.2      Setosa
# 2             4.7          3.2           1.3          0.2      Setosa
# 3             4.6          3.1           1.5          NaN      Setosa
# 4             5.0          3.6           1.4          0.2      Setosa
# 5             5.4          3.9           1.7          0.4      Setosa
# 6             NaN          3.4           1.4          0.3      Setosa
# 7             NaN          3.4           1.5          0.2      Setosa
# 8             4.4          2.9           1.4          0.2      Setosa
# 9             4.9          3.1           1.5          0.1         NaN
# 10            5.4          3.7           1.5          0.2      Setosa
# 11            4.8          NaN           1.6          0.2         NaN
# ...

# %%
# 2. Điền các giá trị bị thiếu của dữ liệu theo phương pháp trung bình với các trường có giá trị số và theo phương pháp tần số cao nhất với giá trị rời rạc
df=data.copy()
# numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
df['sepal.length'].fillna(round(data['sepal.length'].mean()),inplace=True)
df['sepal.width'].fillna(round(data['sepal.width'].mean()),inplace=True)
df['petal.length'].fillna(round(data['petal.length'].mean()),inplace=True)
df['petal.width'].fillna(round(data['petal.width'].mean()),inplace=True)
df['variety'].fillna(df['variety'].mode()[0], inplace = True)
display(df)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 0             5.1          3.5           1.4          0.2      Setosa
# 1             4.9          3.0           4.0          0.2      Setosa
# 2             4.7          3.2           1.3          0.2      Setosa
# 3             4.6          3.1           1.5          1.0      Setosa
# 4             5.0          3.6           1.4          0.2      Setosa
# 5             5.4          3.9           1.7          0.4      Setosa
# 6             6.0          3.4           1.4          0.3      Setosa
# 7             6.0          3.4           1.5          0.2      Setosa
# 8             4.4          2.9           1.4          0.2      Setosa
# 9             4.9          3.1           1.5          0.1   Virginica
# 10            5.4          3.7           1.5          0.2      Setosa
# 11            4.8          3.0           1.6          0.2   Virginica
# ...

# %%
#3. Hiển thị các bản ghi có sepal.length > 5 và sepal.width > 3
filtered_df = df[(df['sepal.length'] > 5) & (df['sepal.width'] > 3)]
display(filtered_df)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 0             5.1          3.5           1.4          0.2      Setosa
# 5             5.4          3.9           1.7          0.4      Setosa
# 6             6.0          3.4           1.4          0.3      Setosa
# 7             6.0          3.4           1.5          0.2      Setosa
# 10            5.4          3.7           1.5          0.2      Setosa
# 15            5.7          4.4           1.5          1.0      Setosa
# 16            5.4          3.9           1.3          0.4      Setosa
# 17            5.1          3.5           1.4          0.3   Virginica
# 18            5.7          3.8           1.7          1.0      Setosa
# 19            5.1          3.8           1.5          0.3      Setosa
# 20            5.4          3.4           4.0          0.2      Setosa
# 21            5.1          3.7           4.0          0.4      Setosa
# ...

# %%
# 4. Chuẩn hóa dữ liệu theo min max
df1=df.copy();
for column in ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']:
    min_value = df1[column].min()
    max_value = df1[column].max()
    df1[column] = (df1[column] - min_value) / (max_value - min_value)

display(df1)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 0        0.222222     0.625000      0.067797     0.041667      Setosa
# 1        0.166667     0.416667      0.508475     0.041667      Setosa
# 2        0.111111     0.500000      0.050847     0.041667      Setosa
# 3        0.083333     0.458333      0.084746     0.375000      Setosa
# 4        0.194444     0.666667      0.067797     0.041667      Setosa
# 5        0.305556     0.791667      0.118644     0.125000      Setosa
# 6        0.472222     0.583333      0.067797     0.083333      Setosa
# 7        0.472222     0.583333      0.084746     0.041667      Setosa
# 8        0.027778     0.375000      0.067797     0.041667      Setosa
# 9        0.166667     0.458333      0.084746     0.000000   Virginica
# 10       0.305556     0.708333      0.084746     0.041667      Setosa
# 11       0.138889     0.416667      0.101695     0.041667   Virginica
# ...

# %%
# 5. Liên tục hóa thuộc tính variety
label_encoder = LabelEncoder()
df2 = df.copy()
df2['variety'] = label_encoder.fit_transform(df2['variety'])
display(df2)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           4.0          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          1.0        0
# 4             5.0          3.6           1.4          0.2        0
# 5             5.4          3.9           1.7          0.4        0
# 6             6.0          3.4           1.4          0.3        0
# 7             6.0          3.4           1.5          0.2        0
# 8             4.4          2.9           1.4          0.2        0
# 9             4.9          3.1           1.5          0.1        2
# 10            5.4          3.7           1.5          0.2        0
# 11            4.8          3.0           1.6          0.2        2
# 12            4.8          3.0           1.4          0.1        0
# ...

# %%
#6. Xây dựng mô hình hồi quy tuyến tính để đoán kết quả của thuộc tính variety  dựa trên các thuộc tính khác
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import pandas as pd
# Định nghĩa đặc trưng (X) và mục tiêu (y)
X = df2.drop('variety', axis=1)
y = df2['variety']
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#7. Lấy mẫu ngẫu nhiên có lặp lại 50% dữ liệu
sampled = df.sample(frac=0.5, replace=True, random_state=1)
display(sampled)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 37            4.9          3.6           1.4          0.1      Setosa
# 140           6.7          3.0           4.0          2.4   Virginica
# 72            6.3          2.5           4.9          1.5  Versicolor
# 137           6.4          3.1           5.5          1.8   Virginica
# 133           6.0          2.8           5.1          1.0   Virginica
# 79            5.7          2.6           3.5          1.0  Versicolor
# 144           6.7          3.0           5.7          2.5   Virginica
# 129           7.2          3.0           5.8          1.6   Virginica
# 71            6.1          2.8           4.0          1.3   Virginica
# 134           6.1          2.6           5.6          1.4   Virginica
# 25            5.0          3.0           1.6          0.2      Setosa
# 20            5.4          3.4           4.0          0.2      Setosa
# ...

# %%
#8. Rời rạc hóa thuộc tính sepal.length
df['sepal.length.discrete'] = pd.cut(df['sepal.length'], bins=3, labels=False)
display(df)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety  \
# 0             5.1          3.5           1.4          0.2      Setosa
# 1             4.9          3.0           4.0          0.2      Setosa
# 2             4.7          3.2           1.3          0.2      Setosa
# 3             4.6          3.1           1.5          1.0      Setosa
# 4             5.0          3.6           1.4          0.2      Setosa
# 5             5.4          3.9           1.7          0.4      Setosa
# 6             6.0          3.4           1.4          0.3      Setosa
# 7             6.0          3.4           1.5          0.2      Setosa
# 8             4.4          2.9           1.4          0.2      Setosa
# 9             4.9          3.1           1.5          0.1   Virginica
# 10            5.4          3.7           1.5          0.2      Setosa
# 11            4.8          3.0           1.6          0.2   Virginica
# ...

# %%
# 9. Phân cụm dữ liệu và loại bỏ ngoại lai
from sklearn.cluster import KMeans
from sklearn.ensemble import IsolationForest
kmeans = KMeans(n_clusters=3, random_state=1)
df['cluster'] = kmeans.fit_predict(df.drop('variety', axis=1))

iso_forest = IsolationForest(contamination=0.1, random_state=1)
df['outlier'] = iso_forest.fit_predict(df.drop(['variety', 'cluster'], axis=1))
data_filter = df[df['outlier'] == 1].drop('outlier', axis=1)
new_data=data_filter.drop('sepal.length.discrete', axis=1)
display(new_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
#      sepal.length  sepal.width  petal.length  petal.width     variety  cluster
# 0             5.1          3.5           1.4          0.2      Setosa        0
# 1             4.9          3.0           4.0          0.2      Setosa        2
# 2             4.7          3.2           1.3          0.2      Setosa        0
# 3             4.6          3.1           1.5          1.0      Setosa        0
# 4             5.0          3.6           1.4          0.2      Setosa        0
# 5             5.4          3.9           1.7          0.4      Setosa        0
# ...
